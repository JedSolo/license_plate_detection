# %% [markdown]
# ## Importing libraries

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import cv2
import PIL as pl
import pandas as pd
import splitfolders
import os

# %% [markdown]
# ### Inference with yolov5

# %%
# loading trained model
model = torch.hub.load('ultralytics/yolov5', 'custom', path=r'C:\Users\SolomonSarfo\Documents\Projects\License Plate Detection\yolov5\pretrained_weights\weights\best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\SolomonSarfo/.cache\torch\hub\master.zip
# YOLOv5  2022-10-21 Python-3.9.7 torch-1.11.0 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
# image sample
img = os.path.join(r'C:\Users\SolomonSarfo\Documents\Projects\License Plate Detection\license_plate_detection\test_images\cadillac-7304111_1920.jpg')

# inference
result = model(img)
result.print()

# view result
# %matplotlib inline
plt.figure(figsize=(15,10))
plt.imshow(np.squeeze(result.render()))
plt.show()
plt.savefig('results\img1.jpg')
# Out:
# image 1/1: 1280x1920 1 license plate
# Speed: 51.8ms pre-process, 146.1ms inference, 0.0ms NMS per image at shape (1, 3, 448, 640)
